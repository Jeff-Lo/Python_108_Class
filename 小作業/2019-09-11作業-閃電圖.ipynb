# %%
1+1
# Out:
# 2

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=[0,8]
y1=[0,320/9]
x2=[0,9]
y2=[0,0]
x3=[9,3]
y3=[0,-80/3]

# %%
plt.xkcd()
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.axis([-6,15,-40,40])
plt.plot(x1,y1,x2,y2,x3,y3,color='yellow')
