# %%
hourglass1=" * * * * * * * * * "
while (hourglass1!="         * "):
    hourglass1.rstrip(" ").rstrip("*")
    hourglass1=hourglass1.rstrip(" ").rstrip("*")
    hourglass1=" "+hourglass1
    print(hourglass1)
hourglass2="         * "
hourglass2.lstrip(" ")
hourglass2="        "+hourglass2.lstrip(" ")+"* "
print(hourglass2)
hourglass2="       "+hourglass2.lstrip(" ")+"* "
print(hourglass2)
hourglass2="      "+hourglass2.lstrip(" ")+"* "
print(hourglass2)
hourglass2="     "+hourglass2.lstrip(" ")+"* "
print(hourglass2)
hourglass2="    "+hourglass2.lstrip(" ")+"* "
print(hourglass2)
hourglass2="   "+hourglass2.lstrip(" ")+"* "
print(hourglass2)
hourglass2="  "+hourglass2.lstrip(" ")+"* "
print(hourglass2)
# Out:
#   * * * * * * * *
#    * * * * * * *
#     * * * * * *
#      * * * * *
#       * * * *
#        * * *
#         * *
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
